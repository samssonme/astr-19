# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
random_num=np.random.uniform(0,1,1000)

# %%
plt.hist(random_num, bins=100)
plt.xlabel("x Axis")
plt.ylabel("y Axis")
plt.title("Uniform random numbers")
plt.savefig("Uniform random numbers.pdf")
plt.show()
