# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
random_num= np.random.randint(1000)

# %%
plt.hist(random_num, bins=100)
plt.ylabel("y Axis")
plt.xlabel("x Axis")
plt.title("Random Integer ")
plt.savefig("random integer.pdf")
plt.show()
